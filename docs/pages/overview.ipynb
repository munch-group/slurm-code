# %% [raw]
# ---
# title: Overview
# aliases:
#   - ../index.html
# ---

# %% [markdown]
# **slurm-code** lets you ...
#
# {{< lipsum 1 >}}
#
# ## Installation
#
# ::: {.panel-tabset}
#
# ## pixi
#
# ```bash
# pixi workspace channel add munch-group
# pixi add slurm-code
# ```
#
# ## conda
#
# ```bash
# conda install -c munch-group slurm-code
# ```
#
# ## pip
#
# ```bash
# pip install slurm-code
# ```
#
# :::
